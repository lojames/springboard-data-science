# %%
import pandas as pd

# %%
df = pd.read_csv('a.csv')

# %%
dfa = df[df['Description'].str.contains('7100') | df['Description'].str.contains('352')]
dfa
# Out:
#           Date                          Description     Amount   Account
# 0   2022-01-01    352W 56th St #5A NY - Maintenance  -1,067.81  CITI 429
# 1   2022-01-03   7100 Blvd East #8D NJ- Maintenance  -1,276.50  CITI 429
# 2   2022-01-03           352W 56th St #5A NY - Rent       2400  CITI 887
# 6   2022-02-01    352W 56th St #5A NY - Maintenance  -1,067.81  CITI 429
# 7   2022-02-01           352W 56th St #5A NY - Rent       2400  CITI 887
# 8   2022-02-03   7100 Blvd East #8D NJ- Maintenance  -1,276.50  CITI 429
# 10  2022-02-15         7100 Blvd East #8D NJ - Rent   3,900.00  CITI 429
# 12  2022-03-01    352W 56th St #5A NY - Maintenance  -1,067.81  CITI 429
# 13  2022-03-02           352W 56th St #5A NY - Rent       2400  CITI 887
# 15  2022-03-03   7100 Blvd East #8D NJ- Maintenance  -1,276.50  CITI 429
# 17  2022-04-01    352W 56th St #5A NY - Maintenance  -1,067.81  CITI 429
# 18  2022-04-04   7100 Blvd East #8D NJ- Maintenance  -1,276.50  CITI 429
# ...

# %%
replaced = dfa['Amount'].str.replace(',','').astype('float')
dfa['Amount'] = replaced
# Out:
# C:\Users\James\AppData\Local\Temp\ipykernel_37276\3061529691.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Amount'] = replaced

# %%
dfa[dfa['Amount'].notna()]
# Out:
#           Date                          Description    Amount   Account
# 0   2022-01-01    352W 56th St #5A NY - Maintenance  -1067.81  CITI 429
# 1   2022-01-03   7100 Blvd East #8D NJ- Maintenance  -1276.50  CITI 429
# 2   2022-01-03           352W 56th St #5A NY - Rent      2400  CITI 887
# 6   2022-02-01    352W 56th St #5A NY - Maintenance  -1067.81  CITI 429
# 7   2022-02-01           352W 56th St #5A NY - Rent      2400  CITI 887
# 8   2022-02-03   7100 Blvd East #8D NJ- Maintenance  -1276.50  CITI 429
# 10  2022-02-15         7100 Blvd East #8D NJ - Rent   3900.00  CITI 429
# 12  2022-03-01    352W 56th St #5A NY - Maintenance  -1067.81  CITI 429
# 13  2022-03-02           352W 56th St #5A NY - Rent      2400  CITI 887
# 15  2022-03-03   7100 Blvd East #8D NJ- Maintenance  -1276.50  CITI 429
# 17  2022-04-01    352W 56th St #5A NY - Maintenance  -1067.81  CITI 429
# 18  2022-04-04   7100 Blvd East #8D NJ- Maintenance  -1276.50  CITI 429
# ...

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 73
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         43 non-null     object
#  1   Description  43 non-null     object
#  2   Amount       42 non-null     float64
#  3   Account      43 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 2.7+ KB

# %%
dfa['Amount'].sum()
# Out:
# 16656.17
